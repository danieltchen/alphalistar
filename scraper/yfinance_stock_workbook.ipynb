# %%
import yfinance as yf

data = yf.Ticker("MSFT")
data.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
import yfinance as yf

data = yf.Ticker("VTI")
data.info
# Out:
# {'phone': '800-523-1036',
#  'longBusinessSummary': 'The fund manager employs an indexing investment approach designed to track the performance of the CRSP U.S. Total Market Index (the “Target Index”), which represents 100% of the investable U.S. stock market, as determined by the index provider. Under normal circumstances, the fund invests at least 80% of its net assets, plus the amount of any borrowings for investment purposes, in the stocks that make up the target index.',
#  'companyOfficers': [],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 362.36,
#  'open': 360.65,
#  'dayLow': 358.802,
#  'dayHigh': 361.96,
#  'regularMarketPreviousClose': 362.36,
#  'regularMarketOpen': 360.65,
#  'regularMarketDayLow': 358.802,
#  'regularMarketDayHigh': 361.96,
#  'trailingPE': 26.747149,
#  'volume': 3136670,
#  'regularMarketVolume': 3136670,
#  'averageVolume': 4764662,
#  'averageVolume10days': 3328590,
#  'averageDailyVolume10Day': 3328590,
# ...

# %%
data.calendar
# Out:
# {'Dividend Date': datetime.date(2026, 6, 11),
#  'Ex-Dividend Date': datetime.date(2026, 5, 21),
#  'Earnings Date': [datetime.date(2026, 7, 30)],
#  'Earnings High': 4.89,
#  'Earnings Low': 4.07,
#  'Earnings Average': 4.24777,
#  'Revenue High': 91239000000,
#  'Revenue Low': 86900000000,
#  'Revenue Average': 87610832320}

# %%
data.analyst_price_targets
# Out:
# {'current': 412.66,
#  'high': 870.0,
#  'low': 400.0,
#  'mean': 561.5561,
#  'median': 562.5}

# %%
data.quarterly_income_stmt
# Out:
#                                                        2026-03-31  \
# Tax Effect Of Unusual Items                           281390000.0
# Tax Rate For Calcs                                           0.19
# Normalized EBITDA                                   48804000000.0
# Total Unusual Items                                  1481000000.0
# Total Unusual Items Excluding Goodwill               1481000000.0
# Net Income From Continuing Operation Net Minori...  31778000000.0
# Reconciled Depreciation                             10167000000.0
# Reconciled Cost Of Revenue                          26828000000.0
# EBITDA                                              50285000000.0
# EBIT                                                40118000000.0
# Net Interest Income                                   -48000000.0
# Interest Expense                                      778000000.0
# Interest Income                                       730000000.0
# ...

# %%
data.history(period="1mo")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-04-13 00:00:00-04:00  373.609985  384.540009  371.019989  384.369995
# 2026-04-14 00:00:00-04:00  387.920013  394.690002  386.519989  393.109985
# 2026-04-15 00:00:00-04:00  398.000000  414.369995  396.730011  411.220001
# 2026-04-16 00:00:00-04:00  419.859985  420.820007  412.140015  420.260010
# 2026-04-17 00:00:00-04:00  424.820007  431.579987  420.690002  422.790009
# 2026-04-20 00:00:00-04:00  421.149994  423.329987  416.299988  418.070007
# 2026-04-21 00:00:00-04:00  420.239990  427.179993  417.200012  424.160004
# 2026-04-22 00:00:00-04:00  426.190002  433.700012  423.670013  432.920013
# 2026-04-23 00:00:00-04:00  419.890015  423.660004  411.410004  415.750000
# 2026-04-24 00:00:00-04:00  416.970001  424.950012  415.799988  424.619995
# 2026-04-27 00:00:00-04:00  422.380005  427.109985  417.070007  424.820007
# 2026-04-28 00:00:00-04:00  424.570007  429.920013  421.899994  429.250000
# ...

# %%
data.option_chain(data.options[0]).calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   MSFT260513C00350000 2026-05-11 17:42:55+00:00   350.0      60.29  60.60
# 1   MSFT260513C00352500 2026-05-11 15:39:43+00:00   352.5      58.40  58.10
# 2   MSFT260513C00355000 2026-04-30 13:58:46+00:00   355.0      51.85  55.65
# 3   MSFT260513C00357500 2026-04-29 19:15:01+00:00   357.5      68.75  53.10
# 4   MSFT260513C00360000 2026-04-29 13:37:49+00:00   360.0      64.35  50.65
# ..                  ...                       ...     ...        ...    ...
# 65  MSFT260513C00515000 2026-05-08 13:48:17+00:00   515.0       0.03   0.00
# 66  MSFT260513C00517500 2026-05-07 14:26:19+00:00   517.5       0.16   0.00
# 67  MSFT260513C00520000 2026-05-06 17:17:07+00:00   520.0       0.03   0.00
# 68  MSFT260513C00522500 2026-04-30 14:20:38+00:00   522.5       0.15   0.00
# 69  MSFT260513C00525000 2026-05-01 14:42:06+00:00   525.0       0.23   0.00
#
# ...

# %%
data.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         11   41     3     0           0
# 1    -1m          9   42     3     0           0
# 2    -2m         10   45     3     0           0
# 3    -3m         10   44     3     0           0

# %%
data.upgrades_downgrades
# Out:
#                                    Firm        ToGrade   FromGrade Action  \
# GradeDate
# 2026-05-06 22:53:27   Tigress Financial            Buy         Buy   main
# 2026-05-01 17:55:26              Stifel           Hold        Hold   main
# 2026-04-30 18:37:18           Bernstein     Outperform  Outperform   main
# 2026-04-30 18:08:38           Citigroup            Buy         Buy   main
# 2026-04-30 15:54:53  Evercore ISI Group     Outperform  Outperform   main
# ...                                 ...            ...         ...    ...
# 2012-04-20 10:18:00       Deutsche Bank            Buy               main
# 2012-04-03 15:53:00                 UBS            Buy               main
# 2012-03-22 11:03:00      Morgan Stanley     Overweight               main
# 2012-03-19 18:00:00      Hilliard Lyons  Long-Term Buy               main
# 2012-03-16 12:19:00      Argus Research            Buy        Hold     up
#
# ...

# %%
data.sustainability
# Out:
# HTTP Error 404:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data.analyst_price_targets
# Out:
# {'current': 412.66,
#  'high': 870.0,
#  'low': 400.0,
#  'mean': 561.5561,
#  'median': 562.5}

# %%
data.earnings_estimate
# Out:
#              avg       low   high  yearAgoEps  numberOfAnalysts  growth
# period
# 0q       4.24777   4.07000   4.89     3.65000                31  0.1638
# +1q      4.62403   4.38000   4.98     4.13000                28  0.1196
# 0y      16.85079  16.69775  17.63    13.64000                24  0.2354
# +1y     19.35454  18.12644  20.57    16.85079                37  0.1486

# %%
data.revenue_estimate
# Out:
#                  avg           low          high  numberOfAnalysts  \
# period
# 0q       87610832320   86900000000   91239000000                39
# +1q      89665223660   87795000000   91451000000                34
# 0y      329462095550  327235000000  333071000000                48
# +1y     383929215340  369086000000  406233368370                53
#
#         yearAgoRevenue  growth
# period
# 0q         76441000000  0.1461
# +1q        77673000000  0.1544
# 0y        281724000000  0.1694
# +1y       329462095550  0.1653

# %%
data.earnings_history
# Out:
#             epsActual  epsEstimate  epsDifference  surprisePercent
# quarter
# 2025-06-30       3.65      3.37669           0.27           0.0809
# 2025-09-30       4.13      3.66355           0.47           0.1273
# 2025-12-31       4.14      3.91702           0.22           0.0569
# 2026-03-31       4.27      4.05827           0.21           0.0522

# %%
data.eps_trend
# Out:
#          current  7daysAgo  30daysAgo  60daysAgo  90daysAgo
# period
# 0q       4.24777   4.24283    4.25802    4.26044    4.26147
# +1q      4.62403   4.55178    4.56609    4.56939    4.57189
# 0y      16.85079  16.80082   16.64591   16.65616   16.64616
# +1y     19.35454  19.31938   18.83292   18.82898   18.83504

# %%
data.eps_revisions
# Out:
#         upLast7days  upLast30days  downLast30days  downLast7Days
# period
# 0q               10             6              16             17
# +1q              10            11               7              7
# 0y               19            20               1              0
# +1y              19            18               9              9

# %%
data.growth_estimates
# Out:
#         stockTrend  indexTrend
# period
# 0q          0.1638      0.2482
# +1q         0.1196      0.2073
# 0y          0.2354      0.2188
# +1y         0.1486      0.1520
# LTG            NaN      0.1220

# %%
data.funds_data

# %%
data.insider_purchases
# Out:
#        Insider Purchases Last 6m     Shares  Trans
# 0                      Purchases    17532.0     13
# 1                          Sales    31762.0      4
# 2    Net Shares Purchased (Sold)   -14230.0     17
# 3      Total Insider Shares Held  6685592.0   <NA>
# 4  % Net Shares Purchased (Sold)     -0.002   <NA>
# 5                   % Buy Shares      0.003   <NA>
# 6                  % Sell Shares      0.005   <NA>

# %%
data.insider_transactions
# Out:
#     Shares     Value URL                                         Text  \
# 0    12320   5045643                  Sale at price 409.52 per share.
# 1     5000   1986750              Purchase at price 397.35 per share.
# 2      145         0      Stock Award(Grant) at price 0.00 per share.
# 3      145         0      Stock Award(Grant) at price 0.00 per share.
# 4      145         0      Stock Award(Grant) at price 0.00 per share.
# ..     ...       ...  ..                                          ...
# 94     138         0      Stock Award(Grant) at price 0.00 per share.
# 95     138         0      Stock Award(Grant) at price 0.00 per share.
# 96   16996         0              Stock Gift at price 0.00 per share.
# 97     566    235535         Sale at price 415.53 - 416.60 per share.
# 98   25000  10641950                  Sale at price 425.68 per share.
#
#              Insider                 Position Transaction Start Date Ownership
# ...

# %%
data.insider_roster_holders
# Out:
#                       Name                 Position URL  \
# 0           ALTHOFF JUDSON                  Officer
# 1              COLEMAN AMY                  Officer
# 2         HOGAN KATHLEEN T                  Officer
# 3               HOOD AMY E  Chief Financial Officer
# 4            JOLLA ALICE L                  Officer
# 5            NADELLA SATYA  Chief Executive Officer
# 6           NUMOTO TAKESHI                  Officer
# 7       SMITH BRADFORD LEE                President
# 8          STANTON JOHN W.                 Director
# 9  YOUNG CHRISTOPHER DAVID                  Officer
#
#   Most Recent Transaction Latest Transaction Date  Shares Owned Directly  \
# 0                    Sale              2025-12-02                 129349
# 1      Stock Award(Grant)              2025-09-15                  45923
# 2                    Sale              2026-03-06                 137933
# 3      Stock Award(Grant)              2025-09-15                 567567
# ...

# %%
data.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.00090
# institutionsPercentHeld          0.78339
# institutionsFloatPercentHeld     0.78410
# institutionsCount             8037.00000

# %%
data.institutional_holders
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2025-12-31                     Blackrock Inc.   0.0810  601897495
# 1    2026-03-31    Vanguard Capital Management LLC   0.0650  482558086
# 2    2025-12-31           State Street Corporation   0.0412  306150608
# 3    2025-12-31                           FMR, LLC   0.0271  200948745
# 4    2025-12-31      Geode Capital Management, LLC   0.0246  182618400
# 5    2026-03-31  Vanguard Portfolio Management LLC   0.0225  167490848
# 6    2025-12-31                JPMORGAN CHASE & CO   0.0199  147759850
# 7    2025-12-31      Price (T.Rowe) Associates Inc   0.0169  125709121
# 8    2025-12-31                     Morgan Stanley   0.0163  121220561
# 9    2025-12-31                        NORGES BANK   0.0141  104761241
#
#           Value  pctChange
# 0  248379022490     0.0170
# 1  199132421535     1.0000
# 2  126336111018     0.0213
# 3   82923509847    -0.0453
# 4   75359309612     0.0106
# ...

# %%
data.mutualfund_holders
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2025-12-31  VANGUARD INDEX FUNDS-Vanguard Total Stock Mark...   0.0314
# 1    2025-12-31       VANGUARD INDEX FUNDS-Vanguard 500 Index Fund   0.0252
# 2    2026-03-31             iShares Trust-iShares Core S&P 500 ETF   0.0128
# 3    2026-03-31  Fidelity Concord Street Trust-Fidelity 500 Ind...   0.0128
# 4    2026-03-31  SPDR S&P 500 ETF TRUST-State Street SPDR S&P 5...   0.0116
# 5    2025-12-31    VANGUARD INDEX FUNDS-Vanguard Growth Index Fund   0.0104
# 6    2026-04-30                        Invesco QQQ Trust, Series 1   0.0078
# 7    2025-12-31  VANGUARD INSTITUTIONAL INDEX FUNDS-Vanguard In...   0.0057
# 8    2026-02-28  VANGUARD WORLD FUND-Vanguard Information Techn...   0.0045
# 9    2026-03-31                             GROWTH FUND OF AMERICA   0.0045
#
#       Shares        Value  pctChange
# 0  233573777  96386555672    -0.0017
# 1  187420611  77340990021     0.0219
# ...

# %%
try:
    from .edgar_wrapper import Company, set_identity, MultiFinancials  # type: ignore
except ImportError:
    from edgar_wrapper import Company, set_identity, MultiFinancials  # type: ignore

identity = f"Alphalistar Limited alphalistai@gmail.com"
set_identity(identity)
symbol = 'GOOGL'
company = Company(symbol)

# latest_10Qs = company.get_filings(form="10-Q")

filings = company.get_filings(form="10-Q")

filing = filings[0]
attachment = filing.attachments[10]

# dir(attachment)

attachment.view()

# content = filing.markdown()
# print(content)
# Out:
#   Cell In[20], line 13
#     filings = company.get_filings(form="10-Q", 1)
#                                                 ^
# SyntaxError: positional argument follows keyword argument
